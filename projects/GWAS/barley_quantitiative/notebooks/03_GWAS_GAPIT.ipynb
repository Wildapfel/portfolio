# %%
import os

# %%
os.makedirs("../report/gapit/", exist_ok=True)

# %%
# %%bash
# #
# # Supposedly, /usr/bin should be accessible from here, but I believe that silverblue
# # prevents execution .... so I must execute GAPIT from the terminal:
# # cd to project dir
# # ./scripts/run_docker_GWAS.sh
# #
# ls -l /usr/bin/pwd
# ! export PATH="/usr/bin:$PATH"
# echo $PATH
# ls -la /usr/bin/docker
# Out:
# -rwxr-xr-x. 5 nfsnobody nfsnobody 58608 Jan  1  1970 /usr/bin/pwd
# /usr/bin:/var/home/maxpetzold/anaconda3/envs/stat-env/bin:/var/home/maxpetzold/bin:/var/home/maxpetzold/anaconda3/envs/stat-env/bin:/var/home/maxpetzold/.local/bin:/var/home/maxpetzold/bin:/app/bin:/app/bin:/usr/bin:/app/bin:/var/home/maxpetzold/.var/app/com.visualstudio.code/data/node_modules/bin:/var/home/maxpetzold/Desktop/HUB/bioinformatics/data_analysis/tools/visualization/igv
# ls: cannot access '/usr/bin/docker': No such file or directory
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '#\n# Supposedly, /usr/bin should be accessible from here, but I believe that silverblue\n# prevents execution .... so I must execute GAPIT from the terminal (check scripts/run_docker_GWAS.sh)\n#\nls -l /usr/bin/pwd\n! export PATH="/usr/bin:$PATH"\necho $PATH\nls -la /usr/bin/docker\n')
#
# File ~/anaconda3/envs/stat-env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/anaconda3/envs/stat-env/lib/python3.13/site-packages/IPython/core/magics/script.py:160, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     158 else:
#     159     line = script
# --> 160 return self.shebang(line, cell)
#
# File ~/anaconda3/envs/stat-env/lib/python3.13/site-packages/IPython/core/magics/script.py:348, in ScriptMagics.shebang(self, line, cell)
#     343 if args.raise_error and p.returncode != 0:
#     344     # If we get here and p.returncode is still None, we must have
#     345     # killed it but not yet seen its return code. We don't wait for it,
#     346     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     347     rc = p.returncode or -9
# --> 348     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'#\n# Supposedly, /usr/bin should be accessible from here, but I believe that silverblue\n# prevents execution .... so I must execute GAPIT from the terminal (check scripts/run_docker_GWAS.sh)\n#\nls -l /usr/bin/pwd\n! export PATH="/usr/bin:$PATH"\necho $PATH\nls -la /usr/bin/docker\n'' returned non-zero exit status 2.
