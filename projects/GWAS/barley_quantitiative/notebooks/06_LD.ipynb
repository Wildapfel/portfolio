# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import matplotlib.pyplot as plt

from codebase.src.plots.Plots import Plots
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
LD = pd.read_csv("../report/LD/LD.BK_15.BK_16.SCRI_RS_155612.SCRI_RS_133377.SCRI_RS_170337.csv", index_col=0)
LD.head()
# Out:
#                 BK_15     BK_16  SCRI_RS_155612  SCRI_RS_133377  \
# BK_15               0  0.897892        0.858679        0.929412
# BK_16               0  0.000000        0.912762        0.854507
# SCRI_RS_155612      0  0.000000        0.000000        0.829136
# SCRI_RS_133377      0  0.000000        0.000000        0.000000
# SCRI_RS_170337      0  0.000000        0.000000        0.000000
#
#                 SCRI_RS_170337
# BK_15                 0.858679
# BK_16                 0.912762
# SCRI_RS_155612        0.958075
# SCRI_RS_133377        0.829136
# SCRI_RS_170337        0.000000

# %%
plots = Plots()

# %%
plots.heatmap(LD, title="LD significant marker", triangle=True, out_file="../report/LD/LD_significant_marker.png")
# Out:
# /var/home/maxpetzold/HUB_local/codebase/src/plots/Plots.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
