# %%
import pandas as pd
import skimage.io as io

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
gapit_TGW = pd.read_csv("../report/gapit/GAPIT.Association.GWAS_Results.FarmCPU.RIP(NYC).csv")

# %%
gapit_TGW.sort_values(by=["P.value"], ascending=True)
# Out:
#                 SNP  Chr    Pos       P.value       MAF  nobs    Effect  \
# 16   SCRI_RS_170337    2   23.0  1.227845e-07  0.233333   120 -0.589781
# 17   SCRI_RS_155612    2   24.8  1.338096e-07  0.225000   120 -1.616176
# 22   SCRI_RS_194318    2   44.4  8.155407e-03  0.158333   120 -0.784845
# 79    SCRI_RS_44952    2  135.6  1.220717e-02  0.404167   120 -0.562108
# 76   SCRI_RS_172784    2  135.6  1.272091e-02  0.412500   120 -0.555938
# 75   BOPA2_12_10950    2  135.6  1.272091e-02  0.412500   120 -0.555938
# 74   BOPA2_12_10487    2  135.6  1.272091e-02  0.412500   120 -0.555938
# 78   SCRI_RS_234587    2  135.6  1.272091e-02  0.412500   120 -0.555938
# 80   SCRI_RS_152664    2  138.6  1.662161e-02  0.420833   120 -0.532354
# 81   SCRI_RS_156013    2  138.6  1.662161e-02  0.420833   120 -0.532354
# 82   SCRI_RS_174077    2  138.6  1.662161e-02  0.420833   120 -0.532354
# 83   SCRI_RS_194653    2  138.6  1.662161e-02  0.420833   120 -0.532354
# ...
