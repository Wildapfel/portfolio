# %%
import pandas as pd

# %%
df_GSE13159= pd.read_csv("/var/home/maxpetzold/HUB_local/projects/personal/transcriptomics/classifier/leukemia/v4.0/data/raw/GSE13159/GSE13159_labels_pb.csv")
df_GSE16455 = pd.read_csv("/var/home/maxpetzold/HUB_local/projects/personal/transcriptomics/classifier/leukemia/v4.0/data/raw/GSE16455/GSE16455_labels.csv")

# %%
df_GSE13159["Disease"].value_counts()
# Out:
# Disease
# CLL                                                448
# AML with normal karyotype + other abnormalities     21
# Pro-B-ALL with t(11q23)/MLL                         15
# c-ALL/Pre-B-ALL with t(9;22)                        11
# CML                                                 10
# AML with t(11q23)/MLL                                9
# c-ALL/Pre-B-ALL without t(9;22)                      5
# AML with t(8;21)                                     5
# T-ALL                                                4
# AML with t(15;17)                                    3
# ALL with t(1;19)                                     3
# AML complex aberrant karyotype                       2
# ALL with hyperdiploid karyotype                      1
# mature B-ALL with t(8;14)                            1
# AML with inv(16)/t(16;16)                            1
# Non-leukemia and healthy bone marrow                 1
# Name: count, dtype: int64

# %%
df_GSE16455["Disease"].value_counts()
# Out:
# Disease
# CLL (Chronic Lymphocytic Leukemia)          17
# cMCL (conventional mantle cell lymphoma)    14
# LF (follicular lymphoma)                     7
# iMCL (indolent mantle cell lymphoma)         7
# SMLZ (Splenic Marginal Zone Lymphoma)        4
# HCL (Hairy Cell Leukemia)                    3
# HCL (Hairy Cell Leukemia)-variant            2
# cMCL (conventional)                          1
# Name: count, dtype: int64
