# %%
import pickle
from scipy.special import expit

# %%
grid_obj = pickle.load(open("../experiments/04_bg_corrected_train_dqn_ext_test_scaled/classifiers/cll_assoc_probes/grid_search/feat_sel_1/svm-linear.pk", "rb"))

# %%
grid_obj["j_opt_t"]
# Out:
# np.float64(1.5487707044593213)

# %%
expit(grid_obj["j_opt_t"])
# Out:
# np.float64(0.8247361124480479)

# %%
grid_obj = pickle.load(open("../experiments/04_bg_corrected_train_dqn_ext_test_scaled/classifiers/cll_assoc_probes/grid_search/feat_sel_1/svm-linear-weighted.pk", "rb"))

# %%
grid_obj["f1_opt_t"]
# Out:
# np.float64(-2.909833676218047)

# %%
expit(grid_obj["f1_opt_t"])
# Out:
# np.float64(0.051669584696884166)
