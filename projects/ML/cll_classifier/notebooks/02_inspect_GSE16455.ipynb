# %%
import pandas as pd

# %%
df = pd.read_csv("../data/GSE16455/GSE16455_merged.csv")

# %%
df.head()
# Out:
#       GSM_ID                               Disease  1007_s_at   1053_at  \
# 0  GSM413603  iMCL (indolent mantle cell lymphoma)   6.414694  5.753344
# 1  GSM413604  iMCL (indolent mantle cell lymphoma)   5.921875  6.215756
# 2  GSM413605  iMCL (indolent mantle cell lymphoma)   5.839085  6.072113
# 3  GSM413606  iMCL (indolent mantle cell lymphoma)   6.284654  6.209722
# 4  GSM413607  iMCL (indolent mantle cell lymphoma)   5.765585  5.412111
#
#      117_at    121_at  1255_g_at   1294_at   1316_at   1320_at  ...  \
# 0  5.961547  6.219107   2.434814  7.510519  4.363502  3.407534  ...
# 1  6.048768  6.117716   2.434836  7.314878  4.611726  3.247037  ...
# 2  6.063328  6.467845   2.524198  8.109449  4.386706  3.590539  ...
# 3  6.161922  6.605082   2.578788  7.114241  4.522149  3.235371  ...
# 4  7.255944  6.187348   2.684251  8.006725  4.965145  4.392647  ...
#
#    AFFX-r2-Ec-bioD-3_at  AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  \
# ...

# %%
df.Disease.value_counts()
# Out:
# Disease
# CLL (Chronic Lymphocytic Leukemia)          17
# cMCL (conventional mantle cell lymphoma)    14
# LF (follicular lymphoma)                     7
# iMCL (indolent mantle cell lymphoma)         7
# SMLZ (Splenic Marginal Zone Lymphoma)        4
# HCL (Hairy Cell Leukemia)                    3
# HCL (Hairy Cell Leukemia)-variant            2
# cMCL (conventional)                          1
# Name: count, dtype: int64
